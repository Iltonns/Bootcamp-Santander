# %% [markdown]
# CRIANDO PIPELINE DE ETL COM PYTHON E IA GENERATIVA

# %%
sdw2023_api_url = 'https://sdw-2023-prd.up.railway.app'

# %% [markdown]
# EXTRACT

# %% [markdown]
# Extraia a lisra de IDs de usuários a partir do arquivo CSV. PRA CADA ID, faça uma requisição GET para obter os dados do usuário correspondente.

# %% [markdown]
# TRANSFORM

# %% [markdown]
# Utilize a API do OpenAI GPT-4 para gerar uma mensagem de marketing personalizada para cada usuário.

# %% [markdown]
# LOAD

# %% [markdown]
# Atualize a lista de news de cada usuário na API com a nova mensagem gerada.
